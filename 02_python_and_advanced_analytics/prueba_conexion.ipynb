# %% [markdown]
# <a href="https://colab.research.google.com/github/FakuDG/data-science-foundations/blob/drafts/02_python_and_advanced_analytics/prueba_conexion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola GitHub")
# Out:
# Hola GitHub
